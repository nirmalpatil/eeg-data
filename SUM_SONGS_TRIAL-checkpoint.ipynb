# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import csv

# %%
data = pd.read_csv(r"C:\Users\Nirmal\Desktop\FYP\FEATURE_TABLE - allthree.csv")

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     T7_kurt   F7_kurt    P3_kurt   FPZ_kurt   F8_kurt   T8_kurt   P4_kurt  \
# 0  0.980058  0.791880   0.226553   0.900038  0.695490  0.570575  0.362540
# 1  8.488381  3.416753   0.179526  10.672150  3.787892  1.405073  1.995299
# 2  6.284698  1.928789   0.471826   3.676500  2.596922  0.646203  1.010835
# 3  4.122412  1.696279   1.140661   1.857882  1.451043  6.585979  4.717690
# 4  1.659244  0.475512  13.800430  -0.135590 -0.135070  0.068055  4.455205
#
#    T7_stdev  F7_stdev  P3_stdev  ...       T8_avg    P4_avg   T7_skew  \
# 0  6945.769  8748.837  6157.904  ...    -87.30610  83.13810 -0.112630
# 1  6852.299  9320.701  6743.797  ...    -38.76500 -25.32250 -0.831180
# 2  6601.032  8831.605  7322.257  ...     69.59693 -65.96910  0.295255
# 3  7035.434  9111.247  6297.682  ...    -68.18930  72.58168 -0.408970
# 4  6063.853  4869.684  1464.423  ...   -224.92800  -8.34703 -0.334800
#
#    F7_skew   P3_skew  FPZ_skew   F8_skew   T8_skew  P4_skew  State
# ...

# %%
sns.pairplot(df,hue='State',palette = 'coolwarm')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['State','T7_var','F7_var','P3_var','FPZ_var','F8_var','T8_var','P4_var','T7_avg','F7_avg','P3_avg','FPZ_avg','F8_avg','T8_avg','P4_avg',
'T7_stdev','F7_stdev','P3_stdev','FPZ_stdev','F8_stdev','T8_stdev','P4_stdev'



           ],axis=1)
y = df['State']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()

# %%
svc_model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
predictions = svc_model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[4 4]
#  [0 7]]

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           1       1.00      0.50      0.67         8
#           2       0.64      1.00      0.78         7
#
# avg / total       0.83      0.73      0.72        15

# %%
svc_model.decision_function(X)
# Out:
# array([-1.15845917, -0.70087746, -0.24400156, -0.78355436, -0.76097977,
#        -0.7613678 , -0.27537101, -0.99997624, -1.02220293, -1.00008122,
#         0.2993929 , -0.7006071 , -1.02736749, -0.7006071 , -0.7006071 ,
#        -0.70061497, -1.00001983, -1.0002269 , -0.7006071 , -0.99973962,
#        -0.7006071 , -0.75840293, -0.73191509,  0.18097648, -1.08601578,
#        -1.12170487, -1.03319036,  0.2993929 , -0.76045648, -1.00020185,
#        -0.7006071 , -0.7006071 , -0.56088529, -0.99999964,  0.2993929 ,
#        -1.00483254,  0.99998256,  0.99998237,  1.00046654,  0.99998256,
#         0.99996783,  0.2993929 ,  0.99998123,  0.99991416,  1.00023463,
#         0.99994015,  0.99994015,  0.2993929 ,  0.2993929 ,  0.9999911 ,
#         0.99974399,  0.99998256,  0.99999191,  0.99995262,  0.99991416,
#         0.99995262,  1.00023463,  1.0001379 ,  0.99997502,  0.2993929 ,
#         0.2993929 ,  0.99997843,  0.99998123,  0.9999911 ,  0.99998256,
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001]}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# ...

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[5 3]
#  [0 7]]

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#              precision    recall  f1-score   support
#
#           1       1.00      0.62      0.77         8
#           2       0.70      1.00      0.82         7
#
# avg / total       0.86      0.80      0.79        15
